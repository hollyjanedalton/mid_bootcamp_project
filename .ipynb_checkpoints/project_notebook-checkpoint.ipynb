# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
# %matplotlib inline

# %%
#xls = pd.ExcelFile('/Users/hollydalton/mid_bootcamp_project/creditcardmarketing.xlsx')
#xls.head()

df = pd.read_excel (r'/Users/hollydalton/mid_bootcamp_project/creditcardmarketing.xlsx')
df
# Out:
#        Customer Number Offer Accepted     Reward Mailer Type Income Level  \
# 0                    1             No  Air Miles      Letter         High
# 1                    2             No  Air Miles      Letter       Medium
# 2                    3             No  Air Miles    Postcard         High
# 3                    4             No  Air Miles      Letter       Medium
# 4                    5             No  Air Miles      Letter       Medium
# ...                ...            ...        ...         ...          ...
# 17995            17996             No  Cash Back      Letter         High
# 17996            17997             No  Cash Back      Letter         High
# 17997            17998             No  Cash Back      Letter         High
# 17998            17999             No  Cash Back      Letter       Medium
# 17999            18000             No  Cash Back      Letter          Low
#
#        # Bank Accounts Open Overdraft Protection Credit Rating  \
# ...

# %%
#numerical continuous variables
#average balance, Q1 Balance, Q2 Balance, Q3 Balance, Q4 Balance

# %%
#change titles to lower case 
lower = []
for i in df.columns:
        lower.append(i.lower())
df.columns = lower

df
# Out:
#        customer number offer accepted     reward mailer type income level  \
# 0                    1             No  Air Miles      Letter         High
# 1                    2             No  Air Miles      Letter       Medium
# 2                    3             No  Air Miles    Postcard         High
# 3                    4             No  Air Miles      Letter       Medium
# 4                    5             No  Air Miles      Letter       Medium
# ...                ...            ...        ...         ...          ...
# 17995            17996             No  Cash Back      Letter         High
# 17996            17997             No  Cash Back      Letter         High
# 17997            17998             No  Cash Back      Letter         High
# 17998            17999             No  Cash Back      Letter       Medium
# 17999            18000             No  Cash Back      Letter          Low
#
#        # bank accounts open overdraft protection credit rating  \
# ...

# %%
#Puts underscore instead of spaces
under_ = []
for i in df.columns:
        if ' ' in i:
            under_.append(i.replace(' ', '_'))
        else:
            under_.append(i)
df.columns = under_   
df
# Out:
#        customer_number offer_accepted     reward mailer_type income_level  \
# 0                    1             No  Air Miles      Letter         High
# 1                    2             No  Air Miles      Letter       Medium
# 2                    3             No  Air Miles    Postcard         High
# 3                    4             No  Air Miles      Letter       Medium
# 4                    5             No  Air Miles      Letter       Medium
# ...                ...            ...        ...         ...          ...
# 17995            17996             No  Cash Back      Letter         High
# 17996            17997             No  Cash Back      Letter         High
# 17997            17998             No  Cash Back      Letter         High
# 17998            17999             No  Cash Back      Letter       Medium
# 17999            18000             No  Cash Back      Letter          Low
#
#        #_bank_accounts_open overdraft_protection credit_rating  \
# ...

# %%
df.dtypes
# Out:
# customer_number           int64
# offer_accepted           object
# reward                   object
# mailer_type              object
# income_level             object
# #_bank_accounts_open      int64
# overdraft_protection     object
# credit_rating            object
# #_credit_cards_held       int64
# #_homes_owned             int64
# household_size            int64
# own_your_home            object
# average_balance         float64
# q1_balance              float64
# q2_balance              float64
# q3_balance              float64
# q4_balance              float64
# dtype: object

# %%
df.describe().T
# Out:
#                         count         mean          std    min      25%  \
# customer_number       18000.0  9000.500000  5196.296758   1.00  4500.75
# #_bank_accounts_open  18000.0     1.255778     0.472501   1.00     1.00
# #_credit_cards_held   18000.0     1.903500     0.797009   1.00     1.00
# #_homes_owned         18000.0     1.203444     0.427341   1.00     1.00
# household_size        18000.0     3.499056     1.114182   1.00     3.00
# average_balance       17976.0   940.515562   350.297837  48.25   787.50
# q1_balance            17976.0   910.450656   620.077060   0.00   392.75
# q2_balance            17976.0   999.392190   457.402268   0.00   663.00
# q3_balance            17976.0  1042.033600   553.452599   0.00   633.00
# q4_balance            17976.0   810.185803   559.001365   0.00   363.00
#
#                          50%       75%       max
# customer_number       9000.5  13500.25  18000.00
# #_bank_accounts_open     1.0      1.00      3.00
# ...

# %%
df.isnull().sum()/len(df)
#null values all of same % in average_balance, q1_balance, q2_balance, q3_balance, q4_balance     
#of 0.001333 (less than 1%)
# Out:
# customer_number         0.000000
# offer_accepted          0.000000
# reward                  0.000000
# mailer_type             0.000000
# income_level            0.000000
# #_bank_accounts_open    0.000000
# overdraft_protection    0.000000
# credit_rating           0.000000
# #_credit_cards_held     0.000000
# #_homes_owned           0.000000
# household_size          0.000000
# own_your_home           0.000000
# average_balance         0.001333
# q1_balance              0.001333
# q2_balance              0.001333
# q3_balance              0.001333
# q4_balance              0.001333
# dtype: float64

# %%
df.isnull().sum()
# Out:
# customer_number          0
# offer_accepted           0
# reward                   0
# mailer_type              0
# income_level             0
# #_bank_accounts_open     0
# overdraft_protection     0
# credit_rating            0
# #_credit_cards_held      0
# #_homes_owned            0
# household_size           0
# own_your_home            0
# average_balance         24
# q1_balance              24
# q2_balance              24
# q3_balance              24
# q4_balance              24
# dtype: int64

# %%
#Exploring target variable values
df['offer_accepted']. value_counts()
# Out:
# No     16977
# Yes     1023
# Name: offer_accepted, dtype: int64

# %%
sns.displot(df['offer_accepted'])
plt.show()
#many more No than Yes. will need to deal with imbalanced data later when building logistic regression model

# %%
df.duplicated()
print(df[df.duplicated()])
#there are no duplicate rows
# Out:
# Empty DataFrame
# Columns: [customer_number, offer_accepted, reward, mailer_type, income_level, #_bank_accounts_open, overdraft_protection, credit_rating, #_credit_cards_held, #_homes_owned, household_size, own_your_home, average_balance, q1_balance, q2_balance, q3_balance, q4_balance]
# Index: []

# %%
df.nunique()
#Yes/No columns: offer_accepted, overdraft_protection, own_your_home
# Out:
# customer_number         18000
# offer_accepted              2
# reward                      3
# mailer_type                 2
# income_level                3
# #_bank_accounts_open        3
# overdraft_protection        2
# credit_rating               3
# #_credit_cards_held         4
# #_homes_owned               3
# household_size              8
# own_your_home               2
# average_balance          4728
# q1_balance               2158
# q2_balance               1945
# q3_balance               2281
# q4_balance               2184
# dtype: int64

# %% [markdown]
# ### Exporation and Visualization of the type of values in each features

# %%
df['reward'].value_counts()
#Categorical variable, 3 input options, these are 3 types of credit card rewards offered
#Could be important later to see which customers accept which type of credit card reward system
#among customers who ACCEPTED offer, which reward system was chosen the most?
# Out:
# Air Miles    6061
# Cash Back    5999
# Points       5940
# Name: reward, dtype: int64

# %%
sns.displot(df['reward'])
plt.show()
#can see almost exact number of each reward was offered, almost "constant"
#this is important because will give us a very clear view of reward was most accepted

# %%
df['mailer_type'].value_counts()
#customers were either sent a postcard or a letter, about 50/50 split
#postcard would be cheaper than a letter, but letter is more personalized and costs more to send, uses more paper
#interesting to check this over offer_accepted, does it make a difference if sent a postcard or a letter?
# Out:
# Postcard    9147
# Letter      8853
# Name: mailer_type, dtype: int64

# %%
sns.displot(df['mailer_type'])
plt.show()

# %%
df['income_level'].value_counts()
#so income is a $ numerical value, but in this dataframe income has already been binned into 3 categories
#we don't have the info to know what the cut off points are for these bins 
#categorical variable
# Out:
# Medium    9013
# High      4526
# Low       4461
# Name: income_level, dtype: int64

# %%
sns.displot(df['income_level'])
plt.show()   #"medium" income level almost double of the other 2 (high and low)

# %%
df['overdraft_protection'].value_counts()
#how much does overdraft protection cost? 
#why don't more customers have overdraft protection?
#only about 17% of customers have overdraft protection
# Out:
# No     15322
# Yes     2678
# Name: overdraft_protection, dtype: int64

# %%
sns.displot(df['overdraft_protection'])
plt.show()

# %%
df['credit_rating'].value_counts()
#credit_rating is a numerical feature that has been binned into 3 values
#categorical feature that is representing binned numerical values
#we don't know what this bank considered a high, medium, low credit score
#I know that more than score of 800 is considered excellent

#customers seem pretty evenly distributed over the 3 credit score ratings
#slightly more in the "high" category than in the other 2
# Out:
# High      6071
# Medium    5972
# Low       5957
# Name: credit_rating, dtype: int64

# %%
sns.displot(df['credit_rating'])
plt.show() 
#noticing that these binned numerical features have used the binning method where each 
#bin has about the same count. 
#qcut bins- aim for all bins to be equally filled, it's a bit artificial

# %%
df['#_credit_cards_held'].value_counts()
#all customers have at least ONE credit card already at this bank
#customers could also have credit cards/accounts with other banks too, of course
# Out:
# 2    7944
# 1    6154
# 3    3387
# 4     515
# Name: #_credit_cards_held, dtype: int64

# %%
sns.displot(df['#_credit_cards_held'])
plt.show() 
#discrete variable

# %%
#bank_accounts_open   --  How many non-credit-card accounts are held by the customer?

df['#_bank_accounts_open'].value_counts()
# Out:
# 1    13692
# 2     4012
# 3      296
# Name: #_bank_accounts_open, dtype: int64

# %%
sns.displot(df['#_bank_accounts_open'])
plt.show()

# %%
df['#_homes_owned'].value_counts()
# Out:
# 1    14523
# 2     3292
# 3      185
# Name: #_homes_owned, dtype: int64

# %%
sns.displot(df['#_homes_owned'])
plt.show() 
#of those who own a home, vast majority only own 1 home
#shouldn't 0 be an option here?

# %%
df['household_size'].value_counts()
# Out:
# 3    5712
# 4    5543
# 5    2853
# 2    2813
# 1     539
# 6     538
# 8       1
# 9       1
# Name: household_size, dtype: int64

# %%
sns.displot(df['household_size'])
plt.show()

# %%
df['own_your_home'].value_counts()
#if there are 6,345 customers who don't own their home, why are there no 0's for the feature
# number of homes owned?
# Out:
# Yes    11655
# No      6345
# Name: own_your_home, dtype: int64

# %%
#Average Balance: Average account balance (across all accounts over time). Q1, Q2, Q3, and Q4

#Q1, Q2, Q3, Q4 Balance: The average balance for each quarter in the last year
sns.displot(df['average_balance'])
plt.show()

# %%
df[['average_balance']].boxplot()
plt.show()

# %%
df['average_balance'].describe()
# Out:
# count    17976.000000
# mean       940.515562
# std        350.297837
# min         48.250000
# 25%        787.500000
# 50%       1007.000000
# 75%       1153.250000
# max       3366.250000
# Name: average_balance, dtype: float64

# %% [markdown]
# ### Using scatterplots to compare 2 distinct variables

# %%
df.dtypes
# Out:
# customer_number           int64
# offer_accepted           object
# reward                   object
# mailer_type              object
# income_level             object
# #_bank_accounts_open      int64
# overdraft_protection     object
# credit_rating            object
# #_credit_cards_held       int64
# #_homes_owned             int64
# household_size            int64
# own_your_home            object
# average_balance         float64
# q1_balance              float64
# q2_balance              float64
# q3_balance              float64
# q4_balance              float64
# dtype: object

# %%
sns.scatterplot(x=df['#_bank_accounts_open'], y=df['average_balance'])
plt.show()

# %%
sns.scatterplot(x=df['average_balance'], y=df['q2_balance'])
plt.show()

# %%
sns.scatterplot(x=df['q1_balance'], y=df['q4_balance'])
plt.show()

# %% [markdown]
# #### Dealing with nulls

# %%
df.isnull().sum()
# Out:
# customer_number          0
# offer_accepted           0
# reward                   0
# mailer_type              0
# income_level             0
# #_bank_accounts_open     0
# overdraft_protection     0
# credit_rating            0
# #_credit_cards_held      0
# #_homes_owned            0
# household_size           0
# own_your_home            0
# average_balance         24
# q1_balance              24
# q2_balance              24
# q3_balance              24
# q4_balance              24
# dtype: int64

# %%
df_nulls = df[df['average_balance'].isna()==True] # Since these nulls are not a lot, we can filter them
df_nulls

#so looks like there are 24 customers with NaN values in their account features
#let's just drop these rows, 24 out of 16,000 is very few
# Out:
#        customer_number offer_accepted     reward mailer_type income_level  \
# 323                324             No     Points    Postcard       Medium
# 3070              3071            Yes  Air Miles    Postcard          Low
# 3108              3109             No  Air Miles      Letter          Low
# 3789              3790             No  Air Miles      Letter       Medium
# 5083              5084             No     Points      Letter       Medium
# 5677              5678             No  Air Miles    Postcard          Low
# 5689              5690             No  Air Miles    Postcard       Medium
# 6932              6933             No  Air Miles    Postcard       Medium
# 7787              7788             No  Air Miles      Letter          Low
# 7864              7865             No  Cash Back    Postcard         High
# 8151              8152             No  Cash Back      Letter          Low
# 8634              8635             No  Air Miles    Postcard         High
# ...

# %%
df = df[df['average_balance'].isna()==False] # Since these nulls are not a lot, we can filter them
df.isnull().sum()
#now there are no nulls!
# Out:
# customer_number         0
# offer_accepted          0
# reward                  0
# mailer_type             0
# income_level            0
# #_bank_accounts_open    0
# overdraft_protection    0
# credit_rating           0
# #_credit_cards_held     0
# #_homes_owned           0
# household_size          0
# own_your_home           0
# average_balance         0
# q1_balance              0
# q2_balance              0
# q3_balance              0
# q4_balance              0
# dtype: int64

# %%
#next-- continue EDA, target against each feature (or just choose a few to visualize)
#finish data prep and prep variables for model ( encoding, scaling, etc)
#what is the correct order to do these in?

# %% [markdown]
# #### Taking closer look at own_your_home and #_homes_owned features

# %%
#make dataframe where 'own your home' = No

# %%
df_homes = df[df["own_your_home"] == 'No'] 
df_homes.shape
df_homes['#_homes_owned'].value_counts()
#this doesn't make sense. own your home = no, but # of homes owned is 1, 2, or 3?
#Poorly recorded data, not sure what issue is exactly.
# Out:
# 1    5134
# 2    1137
# 3      69
# Name: #_homes_owned, dtype: int64

# %% [markdown]
# #### If a customer doesn't own their home ("own_your_home" = No), replace #_homes_owned with 0

# %%
#in original df, where "own_your_home" = No, change "#_homes_owned" to 0
#there should at least be SOME customers who don't own their home, doesn't make sense for ALL customers
#to own at least one home. Also seems odd that only  1/3 of customers don't own a home. 

#df['#_homes_owned'] = df['#_homes_owned'].replace(['old value'],'new value')


df['#_homes_owned'] = np.where(df['own_your_home'] == 'No', 0, df['#_homes_owned'])
# Out:
# /var/folders/bp/sgnz3tn51yl4n6c311dg4qwh0000gn/T/ipykernel_11723/1631554399.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['#_homes_owned'] = np.where(df['own_your_home'] == 'No', 0, df['#_homes_owned'])
#        customer_number offer_accepted     reward mailer_type income_level  \
# 0                    1             No  Air Miles      Letter         High
# 1                    2             No  Air Miles      Letter       Medium
# 2                    3             No  Air Miles    Postcard         High
# 3                    4             No  Air Miles      Letter       Medium
# 4                    5             No  Air Miles      Letter       Medium
# ...

# %%
df['#_homes_owned'].value_counts()
# Out:
# 1    9368
# 0    6340
# 2    2152
# 3     116
# Name: #_homes_owned, dtype: int64

# %%
#Checking for multi-collinearity

correlations_matrix = df.corr()
correlations_matrix
sns.heatmap(correlations_matrix, annot=True)
plt.show()
#remember heatmap only works for numerical variables
#can see highest correlations are between average balance and the q1-q4 balances, makes sense. 
#will probably need to drop some of these features or put them together into one column somehow
#highest correlation is between q2 balance/average balance and q3 balance/average balance
# q1 and q4 have negative correlation

# %%
#strong correlation (near .5 or more) for average_balance feature and qx_balance (quarterly) features

#q1 = Jan, Feb, March
#q2 = April, May, June
#q3 = July, August, Sept
#q4 = Oct, Nov, Dec

#q2 and q3 are the middle of the year quarters, and they are the most closely correlated with the average balance

#Average balance is the average of the other Q1-Q4 features
#Option1- drop the "average_balance" feature and keep the 4 quarter balances
#problem is, there is still some multi-collineatiy between the "qx_balance" features

#Option2- drop the 4 "qx_balance" features and keep the "average_balance"
#we don't know in which quarters the offers were sent out, and we don't know when the offers were accepted either, 
#so does it really matter knowing the quarterly balances? 
#average_balance isn't highly correlated with any other column... good! 


#Let's go with Option 2- dropped the 4 "qx_balance" features. See below.

# %% [markdown]
# #### In case later after building log reg model, I want to try the model by deleting the average_balance column and keeping the quarterly columns instead, going to rename the dataframe here so I don't lose those columns
#
# #### Also going to delete the customer # column because they are identically distributed and hold no meaning other than to identify specific customers
#
# Before dropping 5 columns, df = df, after dropping, df = df1

# %%
#df.drop(['A'], axis=1)
#can only run this cell once
#df1 = df.drop(['q1_balance'], axis=1)
df1
# Out:
#        customer_number offer_accepted     reward mailer_type income_level  \
# 0                    1             No  Air Miles      Letter         High
# 1                    2             No  Air Miles      Letter       Medium
# 2                    3             No  Air Miles    Postcard         High
# 3                    4             No  Air Miles      Letter       Medium
# 4                    5             No  Air Miles      Letter       Medium
# ...                ...            ...        ...         ...          ...
# 17995            17996             No  Cash Back      Letter         High
# 17996            17997             No  Cash Back      Letter         High
# 17997            17998             No  Cash Back      Letter         High
# 17998            17999             No  Cash Back      Letter       Medium
# 17999            18000             No  Cash Back      Letter          Low
#
#        #_bank_accounts_open overdraft_protection credit_rating  \
# ...

# %%
df1 = df.drop(['customer_number','q1_balance', 'q2_balance', 'q3_balance', 'q4_balance'], axis=1)
df1
# Out:
#       offer_accepted     reward mailer_type income_level  \
# 0                 No  Air Miles      Letter         High
# 1                 No  Air Miles      Letter       Medium
# 2                 No  Air Miles    Postcard         High
# 3                 No  Air Miles      Letter       Medium
# 4                 No  Air Miles      Letter       Medium
# ...              ...        ...         ...          ...
# 17995             No  Cash Back      Letter         High
# 17996             No  Cash Back      Letter         High
# 17997             No  Cash Back      Letter         High
# 17998             No  Cash Back      Letter       Medium
# 17999             No  Cash Back      Letter          Low
#
#        #_bank_accounts_open overdraft_protection credit_rating  \
# 0                         1                   No          High
# 1                         1                   No        Medium
# 2                         2                   No        Medium
# ...

# %%
df1 = df1.reset_index(drop=True)
df1 = df1.drop(['index'], axis=1)
df1
# Out:
#       offer_accepted     reward mailer_type income_level  \
# 0                 No  Air Miles      Letter         High
# 1                 No  Air Miles      Letter       Medium
# 2                 No  Air Miles    Postcard         High
# 3                 No  Air Miles      Letter       Medium
# 4                 No  Air Miles      Letter       Medium
# ...              ...        ...         ...          ...
# 17971             No  Cash Back      Letter         High
# 17972             No  Cash Back      Letter         High
# 17973             No  Cash Back      Letter         High
# 17974             No  Cash Back      Letter       Medium
# 17975             No  Cash Back      Letter          Low
#
#        #_bank_accounts_open overdraft_protection credit_rating  \
# 0                         1                   No          High
# 1                         1                   No        Medium
# 2                         2                   No        Medium
# ...

# %%
df1.dtypes #all look correct, no numericals hiding as categoricals
# Out:
# offer_accepted           object
# reward                   object
# mailer_type              object
# income_level             object
# #_bank_accounts_open      int64
# overdraft_protection     object
# credit_rating            object
# #_credit_cards_held       int64
# #_homes_owned             int64
# household_size            int64
# own_your_home            object
# average_balance         float64
# dtype: object

# %%
df1.to_csv('df_cleaned.csv')

# %%
correlations_matrix = df1.corr()
correlations_matrix
sns.heatmap(correlations_matrix, annot=True)
plt.show()
#can see now all have very low correlations

# %% [markdown]
# ### Forgot about outliers... take a quick look now.

# %%
#can only have outliers in numerical data 
#There is no such concept of an outlier in the categorical data but categories with very lower
#or very higher frequency than the other categories can be considered as outliers in the categorical data.

# %%
df1.describe()
#min and max seem to be within reason, true reflection of possibilities of data
#in categoricals, I remember that income level and credit rating are qcut binned into low, medium high
#the rest of categoricals just had 2 or 3 options for inputs and nothing had very high or low values
# Out:
#        #_bank_accounts_open  #_credit_cards_held  #_homes_owned  \
# count          17976.000000         17976.000000   17976.000000
# mean               1.255730             1.903427       0.779929
# std                0.472405             0.797086       0.670681
# min                1.000000             1.000000       0.000000
# 25%                1.000000             1.000000       0.000000
# 50%                1.000000             2.000000       1.000000
# 75%                1.000000             2.000000       1.000000
# max                3.000000             4.000000       3.000000
#
#        household_size  average_balance
# count    17976.000000     17976.000000
# mean         3.499110       940.515562
# std          1.114476       350.297837
# min          1.000000        48.250000
# 25%          3.000000       787.500000
# 50%          3.000000      1007.000000
# 75%          4.000000      1153.250000
# max          9.000000      3366.250000

# %% [markdown]
# ### Conclusion-- don't do anything with outliers. There really aren't any of concern
