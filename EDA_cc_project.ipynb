# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('df_cleaned.csv', index_col=[0])
# Out:
#       offer_accepted     reward mailer_type income_level  \
# 0                 No  Air Miles      Letter         High
# 1                 No  Air Miles      Letter       Medium
# 2                 No  Air Miles    Postcard         High
# 3                 No  Air Miles      Letter       Medium
# 4                 No  Air Miles      Letter       Medium
# ...              ...        ...         ...          ...
# 17971             No  Cash Back      Letter         High
# 17972             No  Cash Back      Letter         High
# 17973             No  Cash Back      Letter         High
# 17974             No  Cash Back      Letter       Medium
# 17975             No  Cash Back      Letter          Low
#
#        #_bank_accounts_open overdraft_protection credit_rating  \
# 0                         1                   No          High
# 1                         1                   No        Medium
# 2                         2                   No        Medium
# ...

# %%
data.describe().T
# Out:
#                         count        mean         std    min    25%     50%  \
# #_bank_accounts_open  17976.0    1.255730    0.472405   1.00    1.0     1.0
# #_credit_cards_held   17976.0    1.903427    0.797086   1.00    1.0     2.0
# #_homes_owned         17976.0    0.779929    0.670681   0.00    0.0     1.0
# household_size        17976.0    3.499110    1.114476   1.00    3.0     3.0
# average_balance       17976.0  940.515562  350.297837  48.25  787.5  1007.0
#
#                           75%      max
# #_bank_accounts_open     1.00     3.00
# #_credit_cards_held      2.00     4.00
# #_homes_owned            1.00     3.00
# household_size           4.00     9.00
# average_balance       1153.25  3366.25

# %%
data['offer_accepted'].value_counts()

1021/17976
# Out:
# 0.05679795282599021

# %%
offer_rejected = data.query("offer_accepted =='No'")
offer_rejected   #dataframe holding all clients who did not accept new cc offer
# Out:
#       offer_accepted     reward mailer_type income_level  \
# 0                 No  Air Miles      Letter         High
# 1                 No  Air Miles      Letter       Medium
# 2                 No  Air Miles    Postcard         High
# 3                 No  Air Miles      Letter       Medium
# 4                 No  Air Miles      Letter       Medium
# ...              ...        ...         ...          ...
# 17971             No  Cash Back      Letter         High
# 17972             No  Cash Back      Letter         High
# 17973             No  Cash Back      Letter         High
# 17974             No  Cash Back      Letter       Medium
# 17975             No  Cash Back      Letter          Low
#
#        #_bank_accounts_open overdraft_protection credit_rating  \
# 0                         1                   No          High
# 1                         1                   No        Medium
# 2                         2                   No        Medium
# ...

# %%
offer_rejected.describe()
# Out:
#        #_bank_accounts_open  #_credit_cards_held  #_homes_owned  \
# count          16955.000000         16955.000000   16955.000000
# mean               1.255913             1.903804       0.780419
# std                0.473093             0.796510       0.671269
# min                1.000000             1.000000       0.000000
# 25%                1.000000             1.000000       0.000000
# 50%                1.000000             2.000000       1.000000
# 75%                1.000000             2.000000       1.000000
# max                3.000000             4.000000       3.000000
#
#        household_size  average_balance
# count    16955.000000     16955.000000
# mean         3.502625       940.848894
# std          1.113703       350.408076
# min          1.000000        48.250000
# 25%          3.000000       787.000000
# 50%          3.000000      1007.000000
# 75%          4.000000      1153.375000
# max          8.000000      3366.250000

# %%
data['#_credit_cards_held'].value_counts()
#each customer owns at least one credit card already with the bank
# Out:
# 2    7933
# 1    6147
# 3    3381
# 4     515
# Name: #_credit_cards_held, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.scatter(x=data['#_credit_cards_held'], y=data['#_bank_accounts_open'])
plt.show()

# %%
import matplotlib.pyplot as plt
plt.scatter(x=data['#_credit_cards_held'], y=data['#_bank_accounts_open'])
plt.show()

# %%
sns.scatterplot(data=data, x="#_credit_cards_held", y="#_bank_accounts_open")
plt.show()

# %%
data = pd.DataFrame(data)

# %%
sns.scatterplot(data=data, x=data["#_credit_cards_held"], y=data["#_bank_accounts_open"])
plt.show()

# %%
import seaborn as sns
# %matplotlib inline
sns.countplot(x=data.credit_cards_held)

# %%
cc_data = pd.read_csv('df_cleaned.csv', index_col=[0])
cc_data
# Out:
#       offer_accepted     reward mailer_type income_level  \
# 0                 No  Air Miles      Letter         High
# 1                 No  Air Miles      Letter       Medium
# 2                 No  Air Miles    Postcard         High
# 3                 No  Air Miles      Letter       Medium
# 4                 No  Air Miles      Letter       Medium
# ...              ...        ...         ...          ...
# 17971             No  Cash Back      Letter         High
# 17972             No  Cash Back      Letter         High
# 17973             No  Cash Back      Letter         High
# 17974             No  Cash Back      Letter       Medium
# 17975             No  Cash Back      Letter          Low
#
#        #_bank_accounts_open overdraft_protection credit_rating  \
# 0                         1                   No          High
# 1                         1                   No        Medium
# 2                         2                   No        Medium
# ...

# %%
cc_data.rename(columns = {'#_credit_cards_held' : 'credit_cards_held', '#_homes_owned' : 'homes_owned', '#_bank_accounts_open' : 'bank_accounts_open'}, inplace = True)
cc_data
# Out:
#       offer_accepted     reward mailer_type income_level  bank_accounts_open  \
# 0                 No  Air Miles      Letter         High                   1
# 1                 No  Air Miles      Letter       Medium                   1
# 2                 No  Air Miles    Postcard         High                   2
# 3                 No  Air Miles      Letter       Medium                   2
# 4                 No  Air Miles      Letter       Medium                   1
# ...              ...        ...         ...          ...                 ...
# 17971             No  Cash Back      Letter         High                   1
# 17972             No  Cash Back      Letter         High                   1
# 17973             No  Cash Back      Letter         High                   1
# 17974             No  Cash Back      Letter       Medium                   1
# 17975             No  Cash Back      Letter          Low                   2
#
# ...

# %%
cc_data.to_csv('cc_data.csv')

# %%
read_file = pd.read_csv ('cc_data.csv')
read_file.to_excel ('cc_data.xlsx', index = None, header=True)

# %%
cc_data[cc_data['offer_accepted'] == 'Yes']['own_your_home'].value_counts()
# Out:
# Yes    661
# No     360
# Name: own_your_home, dtype: int64

# %%
cc_data[cc_data['offer_accepted'] == 'No']['own_your_home'].value_counts()
# Out:
# Yes    10975
# No      5980
# Name: own_your_home, dtype: int64

# %%
cc_data['own_your_home'].value_counts()
# Out:
# Yes    11636
# No      6340
# Name: own_your_home, dtype: int64

# %%
cc_data[cc_data['offer_accepted'] == 'Yes']['credit_rating'].value_counts()
# Out:
# Low       633
# Medium    269
# High      119
# Name: credit_rating, dtype: int64

# %%
cc_data[cc_data['offer_accepted'] == 'No']['credit_rating'].value_counts()
# Out:
# High      5945
# Medium    5695
# Low       5315
# Name: credit_rating, dtype: int64

# %%
633/1021
# Out:
# 0.6199804113614104

# %%
cc_data[cc_data['offer_accepted'] == 'No']['income_level'].value_counts()
# Out:
# Medium    8533
# High      4354
# Low       4068
# Name: income_level, dtype: int64

# %%
cc_data[cc_data['offer_accepted'] == 'Yes']['income_level'].value_counts()
# Out:
# Medium    469
# Low       387
# High      165
# Name: income_level, dtype: int64
